# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-общей-информации-и-предобработках-данных" data-toc-modified-id="Изучение-общей-информации-и-предобработках-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение общей информации и предобработках данных</a></span></li><li><span><a href="#Соотношение-видов-объектов-общественного-питания-по-количеству." data-toc-modified-id="Соотношение-видов-объектов-общественного-питания-по-количеству.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Соотношение видов объектов общественного питания по количеству.</a></span></li><li><span><a href="#Cоотношение-сетевых-и-несетевых-заведений-по-количеству." data-toc-modified-id="Cоотношение-сетевых-и-несетевых-заведений-по-количеству.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Cоотношение сетевых и несетевых заведений по количеству.</a></span></li><li><span><a href="#Для-какого-вида-объекта-общественного-питания-характерно-сетевое-распространение?" data-toc-modified-id="Для-какого-вида-объекта-общественного-питания-характерно-сетевое-распространение?-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Для какого вида объекта общественного питания характерно сетевое распространение?</a></span></li><li><span><a href="#Что-характерно-для-сетевых-заведений:-много-заведений-с-небольшим-числом-посадочных-мест-в-каждом-или-мало-заведений-с-большим-количеством-посадочных-мест?" data-toc-modified-id="Что-характерно-для-сетевых-заведений:-много-заведений-с-небольшим-числом-посадочных-мест-в-каждом-или-мало-заведений-с-большим-количеством-посадочных-мест?-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?</a></span></li><li><span><a href="#Для-каждого-вида-объекта-общественного-питания-опишите-среднее-количество-посадочных-мест.-Какой-вид-предоставляет-в-среднем-самое-большое-количество-посадочных-мест?" data-toc-modified-id="Для-каждого-вида-объекта-общественного-питания-опишите-среднее-количество-посадочных-мест.-Какой-вид-предоставляет-в-среднем-самое-большое-количество-посадочных-мест?-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Для каждого вида объекта общественного питания опишите среднее количество посадочных мест. Какой вид предоставляет в среднем самое большое количество посадочных мест?</a></span></li><li><span><a href="#Выделите-в-отдельный-столбец-информацию-об-улице-из-столбца-address-." data-toc-modified-id="Выделите-в-отдельный-столбец-информацию-об-улице-из-столбца-address-.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выделите в отдельный столбец информацию об улице из столбца address .</a></span></li><li><span><a href="#Постройте-график-топ-10-улиц-по-количеству-объектов-общественного-питания.-Воспользуйтесь-внешней-информацией-и-ответьте-на-вопрос-—-в-каких-районах-Москвы-находятся-эти-улицы?" data-toc-modified-id="Постройте-график-топ-10-улиц-по-количеству-объектов-общественного-питания.-Воспользуйтесь-внешней-информацией-и-ответьте-на-вопрос-—-в-каких-районах-Москвы-находятся-эти-улицы?-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Постройте график топ-10 улиц по количеству объектов общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?</a></span></li><li><span><a href="#Найдите-число-улиц-с-одним-объектом-общественного-питания.-Воспользуйтесь-внешней-информацией-и-ответьте-на-вопрос-—-в-каких-районах-Москвы-находятся-эти-улицы?" data-toc-modified-id="Найдите-число-улиц-с-одним-объектом-общественного-питания.-Воспользуйтесь-внешней-информацией-и-ответьте-на-вопрос-—-в-каких-районах-Москвы-находятся-эти-улицы?-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Найдите число улиц с одним объектом общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?</a></span></li><li><span><a href="#Посмотрите-на-распределение-количества-посадочных-мест-для-улиц-с-большим-количеством-объектов-общественного-питания.-Какие-закономерности-можно-выявить?" data-toc-modified-id="Посмотрите-на-распределение-количества-посадочных-мест-для-улиц-с-большим-количеством-объектов-общественного-питания.-Какие-закономерности-можно-выявить?-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Посмотрите на распределение количества посадочных мест для улиц с большим количеством объектов общественного питания. Какие закономерности можно выявить?</a></span></li><li><span><a href="#Вывод-и-рекомендации" data-toc-modified-id="Вывод-и-рекомендации-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Вывод и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Рынок заведений общественного питания Москвы

# %% [markdown]
# Для открытия небольшого кафе в Москве, где гостей должны обслуживать роботы. Нужно подготовить исследование рынка, на основе открытых данных о заведениях общественного питания в Москве.
#
# **Описание данных**
#
# **Таблица rest_data:**
#    * id — идентификатор объекта;
#    * object_name — название объекта общественного питания;
#    * chain — сетевой ресторан;
#    * object_type — тип объекта общественного питания;
#    * address — адрес;
#    * number — количество посадочных мест.

# %% [markdown]
# ## Изучение общей информации и предобработках данных

# %%
import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import requests
import re
import pandas as pd
import scipy.stats as sps
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots

pd.options.display.max_columns = None

# %%
sns.set(style='darkgrid', palette='Set2', font='sans-serif')
#загрузили стиль для всех графиков

# %%
data=pd.read_csv('rest_data.csv')

# %%
data.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 СМЕТАНА   нет        кафе
# 1   77874                  Родник   нет        кафе
# 2   24309         Кафе «Академия»   нет        кафе
# 3   21894              ПИЦЦЕТОРИЯ    да        кафе
# 4  119365  Кафе «Вишневая метель»   нет        кафе
#
#                                              address  number
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15366 entries, 0 to 15365
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           15366 non-null  int64
#  1   object_name  15366 non-null  object
#  2   chain        15366 non-null  object
#  3   object_type  15366 non-null  object
#  4   address      15366 non-null  object
#  5   number       15366 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 720.4+ KB

# %%
data['object_type'].unique()
#посмотрели уникальные названия типов объектов
# Out:
# array(['кафе', 'столовая', 'закусочная',
#        'предприятие быстрого обслуживания', 'ресторан', 'кафетерий',
#        'буфет', 'бар', 'магазин (отдел кулинарии)'], dtype=object)

# %%
def name(i):
    if i == 'предприятие быстрого обслуживания':
        return 'фаст-фуд'
    if i == 'магазин (отдел кулинарии)':
        return 'отдел кулинарии'
    if i == i:
        return i
data['object_type']=data['object_type'].apply(name)
#заменили название с "предприятие быстрого обслуживания" на "фаст-фуд", чтобы в графиках было читаемее.

# %%
data.duplicated().sum()
data.isna().sum()
#проверили на дубликаты и пропущенные значения
# Out:
# 0
# id             0
# object_name    0
# chain          0
# object_type    0
# address        0
# number         0
# dtype: int64

# %%
data['object_name']=data['object_name'].str.lower()
#привели названия общественных заведений к единому регистру

# %%
data.duplicated(subset=['object_name', 'object_type', 'chain', 'address', 'number']).sum()
#проверили наличие дубликатов по определенным столбцам
# Out:
# 85

# %%
data.drop_duplicates(subset=['object_name', 'object_type', 'chain', 'address', 'number'], inplace=True)
data.duplicated(subset=['object_name', 'object_type', 'chain', 'address', 'number']).sum()
#удалили дубликаты
# Out:
# 0

# %% [markdown]
# Изучив все данные привели все строки с названием объектов к единмоу регистру, также избавились от дубликатов. Можно приступить к дальнейшему анализу объектов общественного питания.

# %% [markdown]
# ## Соотношение видов объектов общественного питания по количеству.

# %%
type1 = data.groupby(['object_type']).agg({'id':'count'}).reset_index().sort_values(by='id', ascending=False)
type1['%']= ((type1['id'] / type1['id'].sum()) * 100).round(2)
data.id.nunique()
type1
#cгруппировали данные по виду объекта общ.питания и их количеству, вывели процент объекта от общего кол-ва
# Out:
# 15281
#        object_type    id      %
# 3             кафе  6071  39.73
# 7         столовая  2584  16.91
# 6         ресторан  2282  14.93
# 8         фаст-фуд  1897  12.41
# 0              бар   855   5.60
# 1            буфет   576   3.77
# 4        кафетерий   395   2.58
# 2       закусочная   348   2.28
# 5  отдел кулинарии   273   1.79

# %%
plt.figure(figsize=(14, 6));
ax = sns.barplot(data=type1,  x="object_type", y="id", color='mediumpurple');
plt.title("Виды объектов общ.питания по количеству");
plt.xlabel("Количество");
plt.ylabel("Виды объектов");
plt.xticks(rotation=45);

for p in ax.patches:
    height = p.get_height();
    ax.text(p.get_x()+p.get_width()/2.,
            height + 2,
            '{:1.0f}'.format(height),
            ha="center");
plt.show();

# %% [markdown]
# Построив график видно, что больше всего объектов общественного питания у вида кафе, заведений такого типа 6 071, на втором месте идет столовая, таких заведений 2 584.

# %% [markdown]
# ## Cоотношение сетевых и несетевых заведений по количеству.

# %%
data.groupby(['chain']).agg({'id':'count'})
(data.id.loc[data['chain']=='да'].nunique() / data.id.count()*100).round(2)
# Out:
#           id
# chain
# да      2964
# нет    12317
# 19.4

# %%
plt.figure(figsize=(8, 5));
ax=sns.barplot(data=data.groupby(['chain']).agg({'id':'count'}).reset_index(), x='chain', y='id');
plt.title("Соотношение сетевых и несетевых заведений");
plt.xlabel("Тип заведения");
plt.ylabel("Количество");
for p in ax.patches:
    height = p.get_height();
    ax.text(p.get_x()+p.get_width()/2.,
            height + 2,
            '{:1.0f}'.format(height),
            ha="center");
plt.show();

# %% [markdown]
# Больше всего в Москве несетевых заведений - 12 317, а сетевых - 2 964.
#
# Процентное соотношение типов заведений:
#    - сетевых - 19.4%
#    - несетевых - 80.6%

# %% [markdown]
# ## Для какого вида объекта общественного питания характерно сетевое распространение?

# %%
chain= (data.pivot_table(index=['object_type', 'chain'], values ='id', aggfunc='count').reset_index()
            .sort_values(by='id', ascending=False))
chain
#создали сводную таблицу с количеством видов объекта сетевого и несетевого распространения
# Out:
#         object_type chain    id
# 7              кафе   нет  4675
# 15         столовая   нет  2581
# 13         ресторан   нет  1739
# 6              кафе    да  1396
# 17         фаст-фуд   нет  1109
# 1               бар   нет   818
# 16         фаст-фуд    да   788
# 3             буфет   нет   565
# 12         ресторан    да   543
# 9         кафетерий   нет   343
# 5        закусочная   нет   292
# 11  отдел кулинарии   нет   195
# 10  отдел кулинарии    да    78
# 4        закусочная    да    56
# 8         кафетерий    да    52
# 0               бар    да    37
# 2             буфет    да    11
# 14         столовая    да     3

# %%
plt.figure(figsize=(14, 6));
ax=sns.barplot(data=chain, y='id', x='object_type', hue='chain')
ax.set(xlabel="Количество видов объекта", ylabel="Виды объектов");
plt.title("Вид распространения сетевое или нет");

for p in ax.patches:
    height = p.get_height();
    ax.text(p.get_x()+p.get_width()/2.,
            height + 2,
            '{:1.0f}'.format(height),
            ha="center");
plt.show();

# %%
chain2= data.pivot_table(index='object_type', columns='chain', values ='id', aggfunc='count').reset_index()
chain2['rate']=chain2['да']/(chain2['да']+chain2['нет']).round(2)
#рассчитали долю сетевых заведений относительно всех заведений каждого типа
chain2=chain2.sort_values(by='rate', ascending=False)
chain2
# Out:
# chain      object_type    да   нет      rate
# 8             фаст-фуд   788  1109  0.415393
# 5      отдел кулинарии    78   195  0.285714
# 6             ресторан   543  1739  0.237949
# 3                 кафе  1396  4675  0.229946
# 2           закусочная    56   292  0.160920
# 4            кафетерий    52   343  0.131646
# 0                  бар    37   818  0.043275
# 1                буфет    11   565  0.019097
# 7             столовая     3  2581  0.001161

# %%
plt.figure(figsize=(14, 6));
ax=sns.barplot(data=chain2, y='rate', x='object_type', color='mediumslateblue')
ax.set(xlabel="Количество видов объекта", ylabel="Виды объектов");
plt.title("Сетевые объекты общественного питания");
#добавили метки на столбцы
for p in ax.patches:
    height = p.get_height();
    ax.text(p.get_x()+p.get_width()/2.,
            height,
            '{:.2%}'.format(height),
            ha="center");
plt.show();

# %% [markdown]
# Сетевое распространение относительно всех заведений каждого типа больше всего характерно для:
#
# - фаст-фуда - 41,54%
# - отдела кулинарии - 28,57%
# - ресторанов - 23,79%
# - кафе - 22,99%

# %% [markdown]
# ## Что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или мало заведений с большим количеством посадочных мест?

# %%
chain_yes = data.query("chain=='да'")  #отберем все сетевые заведения

# %%
chain_yes.groupby('object_name').agg({'id':'count'}).sort_values(by='id', ascending=False).head(15) 
#посмотрим топ-15 сетевых заведений по их количеству, и для них сделаем словарь синонимов, чтобы обработать названия.
# Out:
#                   id
# object_name
# шоколадница      157
# kfc              155
# макдоналдс       150
# бургер кинг      137
# теремок           94
# крошка картошка   90
# домино'с пицца    90
# милти             72
# суши wok          72
# папа джонс        51
# додо пицца        49
# кофе с собой      44
# чайхона №1        43
# хинкальная        38
# якитория          38

# %%
list(chain_yes['object_name'].sort_values().unique())
# Out:
# ['beverly hills diner',
#  'bierloga',
#  'black & white',
#  'bocconcino',
#  'boobo',
#  'bubbleology',
#  'burger club',
#  'coffeeshop',
#  'coffeeshop company',
#  'cofix',
#  'cookhouse',
#  'correas',
#  'costa coffee',
#  'deli by prime прайм-кафе',
#  'dunkin donuts',
#  'florentini',
#  'fridays',
#  'fridays kfc',
#  'glowsubs sandwiches',
#  'goodman гудман',
#  'grand cru',
#  'grand урюк',
#  'healthy food',
#  'il forno иль форно',
#  'jeffreys coffee',
#  'kfc',
#  'kfc волгоградский',
#  'krispy creme',
#  'krispy krem',
#  'lavkalavka',
#  'luciano',
#  'm cafe хинкальная',
#  'maki maki',
#  'marmalato',
#  'marrakesh хинкальная',
#  'moskalyan',
#  'movenpick',
#  'my box',
#  'osteria mario',
#  'panda express',
#  'paul поль',
#  'pizengof99 спб',
#  'prime star прайм стар',
#  'prime прайм стар',
#  'prime прайм стар прайм-кафе',
#  'starbucks',
#  'starbucks coffee',
#  'starbucks кофе',
#  'starbucks старбакс',
#  'starbucks, старбакс кофе',
# ...

# %%
synonyms={'McDonalds':['кафе «макдоналдс»', 'кафе макдоналдс', 'макдоналдс', 'москва - макдоналдс'
                      ,'предприятие быстрого обслуживания «макдоналдс»', 'ресторан «макдоналдс»'
                      ,'ресторан«макдоналдс»'],
'KFC':['kfc', 'kfc волгоградский', 'закусочная kfc', 'закусочная «kfc»', 'кафе kfc', 'кафе «kfc»', 'пбо «kfc покрышкина»',
       'пбо «kfc»', 'предприятие быстрого обслуживания «kfc»','ресторан kfc', 'ресторан «kfc»', 'ресторан быстрого питания kfc'
        'ростикс kfc'],
'бургер кинг':['бургер кинг burger king', 'закусочная «бургер кинг»','кафе «бургер кинг»','кафе-закусочная «бургер кинг»'
               ,'предприятие быстрого обслуживания «бургер кинг»', 'ресторан «бургер кинг»'],
'шоколадница':[ 'кафе «шоколадница»', 'кофейня «шоколадница»', 'шоколадница'],
'starbucks':['starbucks coffee','starbucks кофе','starbucks старбакс','starbucks, старбакс кофе', 'кафе starbucks'
             ,'кафе «starbucks»','старбакс','старбакс starbucks','старбакс кофе'],
'теремок':['закусочная «теремок»','кафе «теремок»', 'кафе теремок', 'пбо «теремок»'
           ,'предприятие быстрого обслуживания «теремок»','ресторан «теремок»','теремок инвест','теремок-инвест',],
'крошка картошка':[ 'закусочная «крошка картошка»', 'кафе «крошка картошка»'
                   ,'предприятие быстрого обслуживания «крошка картошка»','предприятие быстрого питания «крошка картошка»',
                  'ресторан быстрого питания «крошка картошка»',],
"домино'с пицца":["домино'с пицца domino,s pizza", "кафе «домино'с пицца»","пиццерия «домино'с пицца»"
                  ,"предприятие быстрого обслуживания «домино'с пицца»","ресторан «домино'с пицца»",],
'милти':['готовые блюда милти',  'магазин готовой еды «милти»','предприятие быстрого обслуживания «милти»'
         ,'точка продажи готовой еды милти',],
'суши wok':[ 'сеть магазинов «суши wok»','кафе суши wok', 'кафе «суши wok»', 'бар «суши wok»',],
'папа джонс':['кафе «папа джонс»', 'папа джонс пицца', 'пицерия «папа джонс»', 'пиццерия папа джонс'],
'додо пицца': ['пиццерия «додо пицца»', 'предприятие быстрого обслуживания «додо пицца»'],
'чайхона №1':[ 'кафе чайхона №1','павлин мавлин чайхона №1','ресторан «чайхона №1»', 'чайхона №1 бутово',],
'якитория': ['кафе «якитория»', 'кафе якитория', 'ресторан «якитория»', 'якитория и спорт бар', 'якитория и ян примус',]}

def check_synonyms(cell):
    for name, syn in synonyms.items():
        if cell in syn: return name
    return cell

chain_yes['object_name_new']=chain_yes['object_name'].apply(check_synonyms)
data['object_name_new']=data['object_name'].apply(check_synonyms)
chain_yes.head()
#создали словарь синонимов из заведений, которых больше всего в МО. Добавили обновленные названия с помощью функции.
# Out:
#         id object_name chain object_type  \
# 3    21894  пиццетория    да        кафе
# 6   148815    брусника    да        кафе
# 13   22579  алло пицца    да        кафе
# 16  144107    суши wok    да    фаст-фуд
# 18   58565      тануки    да    ресторан
#
#                                               address  number object_name_new
# 3             город Москва, Абрамцевская улица, дом 1      40      пиццетория
# 6       город Москва, переулок Сивцев Вражек, дом 6/2      10        брусника
# 13              город Москва, улица Авиаторов, дом 14      32      алло пицца
# 16                город Москва, Азовская улица, дом 3       7        суши wok
# 18  город Москва, Большая Академическая улица, дом 65     160          тануки

# %%
chain2=chain_yes.groupby('object_name_new').agg({'id':'count', 'number':'mean'}).sort_values(by='id', ascending=False)
#создали таблицу с количеством заведений и средним количеством посадочных мест
chain2['rest']=pd.qcut(chain2['id'], q=[0, 0.75, 1], labels=['Мало заведений', 'Много заведений'])
#разделили количество заведений на 2 группы. Много заведений и мало заведений.
#вместо медианы используем 75%, т.к. у нас много заведений количество которых равно 1.
chain2['number_chain']=pd.qcut(chain2['number'], q=[0, 0.5, 1], labels=['Мало мест','Много мест'])
#разделили количество мест на 2 группы. Мало мест и много мест.
#для расчета на 2 группы используем медиану.

# %%
chain2['Группа']=chain2['rest'].astype(object) + '-' + chain2['number_chain'].astype(object)
chain2.head()
# Out:
#                   id     number             rest number_chain  \
# object_name_new
# шоколадница      179  57.217877  Много заведений   Много мест
# KFC              178  55.730337  Много заведений   Много мест
# McDonalds        172  87.523256  Много заведений   Много мест
# бургер кинг      157  47.675159  Много заведений   Много мест
# теремок          111  27.144144  Много заведений    Мало мест
#
#                                      Группа
# object_name_new
# шоколадница      Много заведений-Много мест
# KFC              Много заведений-Много мест
# McDonalds        Много заведений-Много мест
# бургер кинг      Много заведений-Много мест
# теремок           Много заведений-Мало мест

# %%
chain3=chain2.groupby('Группа').agg({'id':'count', 'number':'mean'}).sort_values(by='id', ascending=False)
chain3['%']= ((chain3['number'] / chain3['number'].sum()) * 100).round(2)
chain3
# Out:
#                              id      number      %
# Группа
# Мало заведений-Мало мест    198   21.352694   8.96
# Мало заведений-Много мест   195  101.566667  42.62
# Много заведений-Мало мест    56   20.822350   8.74
# Много заведений-Много мест   54   94.579901  39.69

# %%
plt.figure(figsize=(8, 5));
sns.scatterplot(data=chain2, x='id', y='number', hue='Группа');
plt.title("Характеристика сетевых заведений");
plt.xlabel("Количество заведений");
plt.ylabel("Среднее количество мест");

# %% [markdown]
# По графику и по сводной таблице видно, что больше всего для сетевых заведений характерно маленькое количество заведений с разным количеством мест, как маленьким так и большим.

# %% [markdown]
# ## Для каждого вида объекта общественного питания опишите среднее количество посадочных мест. Какой вид предоставляет в среднем самое большое количество посадочных мест?

# %%
mean_number=data.pivot_table(index='object_type', values='number', aggfunc='mean').reset_index().sort_values(by='number', 
                                                                                                       ascending=False)
mean_number
#создали сводную таблицу со средним количеством мест для каждогт вида объекта общественного питания.
# Out:
#        object_type      number
# 7         столовая  130.337848
# 6         ресторан   96.884750
# 1            буфет   51.425347
# 0              бар   43.533333
# 3             кафе   39.785703
# 8         фаст-фуд   20.808645
# 4        кафетерий    9.184810
# 2       закусочная    7.847701
# 5  отдел кулинарии    5.589744

# %%
plt.figure(figsize=(15, 8));
ax=sns.barplot(data= mean_number, y='number', x='object_type', color='mediumpurple');
plt.title("Среднеее количество посадочных мест");
plt.xlabel("Места");
plt.ylabel("Вид объекта");

for p in ax.patches:
    height = p.get_height();
    ax.text(p.get_x()+p.get_width()/2.,
            height + 2,
            '{:1.0f}'.format(height),
            ha="center");
plt.show();

# %% [markdown]
# Построив график видно, что самое большое среднее количество посадочных мест у столовой, количество мест равно 130.

# %% [markdown]
# ## Выделите в отдельный столбец информацию об улице из столбца address .

# %%
data['streets']=data['address'].str.replace('город Москва, ', '')
list(data['streets'].sort_values().unique())
#из адреса убрали город Москва.
# Out:
# ['1-й Автозаводский проезд, дом 4, корпус 1',
#  '1-й Автозаводский проезд, дом 5',
#  '1-й Амбулаторный проезд, дом 2, строение 2',
#  '1-й Амбулаторный проезд, дом 8, строение 1',
#  '1-й Балтийский переулок, дом 3/25',
#  '1-й Басманный переулок, дом 3, строение 1',
#  '1-й Ботанический проезд, дом 2',
#  '1-й Боткинский проезд, дом 2/6',
#  '1-й Боткинский проезд, дом 7, строение 1',
#  '1-й Боткинский проезд, дом 9',
#  '1-й Варшавский проезд, дом 1А, строение 9',
#  '1-й Варшавский проезд, дом 6, строение 10',
#  '1-й Вешняковский проезд, дом 2, строение 1',
#  '1-й Волоколамский проезд, дом 10, строение 1',
#  '1-й Волоколамский проезд, дом 10, строение 16',
#  '1-й Волоколамский проезд, дом 9, корпус 1',
#  '1-й Голутвинский переулок, дом 6',
#  '1-й Гончарный переулок, дом 4, строение 1',
#  '1-й Гончарный переулок, дом 4, строение 2',
#  '1-й Грайвороновский проезд, дом 2, строение 10',
#  '1-й Грайвороновский проезд, дом 20А, строение 1',
#  '1-й Дорожный проезд, дом 1',
# ...

# %%
data['streets']=data['streets'].str.replace(', дом +[\w\W]+', '')
data['streets']=data['streets'].str.replace(', владение +[\w\W]+', '')
data['streets']=data['streets'].str.replace(', домовладение +[\w\W]+', '')
#в данном шаге убрали из адреса название дома, владения и домовладения с их номерами. Оставили поселения, поселки и т.д.,
#так как они не входят в город Москва., и не нужны нам для исследования.
data.head()
# Out:
#        id             object_name chain object_type  \
# 0  151635                 сметана   нет        кафе
# 1   77874                  родник   нет        кафе
# 2   24309         кафе «академия»   нет        кафе
# 3   21894              пиццетория    да        кафе
# 4  119365  кафе «вишневая метель»   нет        кафе
#
#                                              address  number  \
# 0         город Москва, улица Егора Абакумова, дом 9      48
# 1  город Москва, улица Талалихина, дом 2/1, корпус 1      35
# 2          город Москва, Абельмановская улица, дом 6      95
# 3            город Москва, Абрамцевская улица, дом 1      40
# 4  город Москва, Абрамцевская улица, дом 9, корпус 1      50
#
#           object_name_new                streets
# 0                 сметана  улица Егора Абакумова
# 1                  родник       улица Талалихина
# 2         кафе «академия»   Абельмановская улица
# 3              пиццетория     Абрамцевская улица
# ...

# %% [markdown]
# Добавили в таблицу столбец streets с названием улицы.

# %% [markdown]
# ## Постройте график топ-10 улиц по количеству объектов общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?

# %%
top10=(data.pivot_table(index=['streets'], values ='id', aggfunc='count').reset_index()
.sort_values(by='id', ascending=False))
top10.query('id>102')
#создали сводную таблицу с топ 10 улиц по кол-ву объектов.
# Out:
#                      streets   id
# 1700           проспект Мира  203
# 996        Профсоюзная улица  182
# 683   Ленинградский проспект  172
# 981   Пресненская набережная  167
# 406         Варшавское шоссе  162
# 686       Ленинский проспект  148
# 1697    проспект Вернадского  128
# 674     Кутузовский проспект  114
# 600          Каширское шоссе  111
# 605     Кировоградская улица  108

# %%
plt.figure(figsize=(15, 8));
ax=sns.barplot(data=top10.query("id>102"), y='id', x='streets', color='mediumpurple')
plt.title("Топ 10 улиц по количеству объектов");
plt.xlabel("Количество");
plt.ylabel("Улица");
plt.xticks(rotation=45)
for p in ax.patches:
    height = p.get_height();
    ax.text(p.get_x()+p.get_width()/2.,
            height + 2,
            '{:1.0f}'.format(height),
            ha="center");
plt.show();

# %% [markdown]
# Построили график с топ-10 улиц по количеству объектов общественного питания.
#
# В топ-10 улиц входит:
#    * проспект Мира;
#    * Профсоюзная улица;
#    * Ленинградский проспект;
#    * Пресненская набережная;
#    * Варшавское шоссе;
#    * Ленинский проспект;
#    * пропект Вернадского;
#    * Кутузовский проспект;
#    * Каширское шоссе;
#    * Кировоградская улица.

# %%
area=pd.read_csv('https://raw.githubusercontent.com/lyutsiyaa/practicum/main/mosgaz-streets.csv')
#загрузили файл с информацией об улицах и  районах Москвы.

# %%
area=area.rename({'streetname':'streets'}, axis=1)
data['streets']=data['streets'].str.lower()
area['streets']=area['streets'].str.lower()
#переименовали столбец для соединения таблиц
area
# Out:
#                               streets  areaid okrug               area
# 0                выставочный переулок      17   ЦАО  Пресненский район
# 1                        улица гашека      17   ЦАО  Пресненский район
# 2             большая никитская улица      17   ЦАО  Пресненский район
# 3                   глубокий переулок      17   ЦАО  Пресненский район
# 4     большой гнездниковский переулок      17   ЦАО  Пресненский район
# ...                               ...     ...   ...                ...
# 4393              вознесенский проезд      17   ЦАО  Пресненский район
# 4394                  волков переулок      17   ЦАО  Пресненский район
# 4395                  поварская улица      17   ЦАО  Пресненский район
# 4396               кудринская площадь      17   ЦАО  Пресненский район
# 4397               вспольный переулок      17   ЦАО  Пресненский район
#
# [4398 rows x 4 columns]

# %%
df = area.merge(data, on='streets', how='inner')
#соединили таблицы

# %%
area10=(df.pivot_table(index=['streets', 'area'], values ='id', aggfunc='count').reset_index()
.sort_values(by='id', ascending=False))
#создали сводную таблицу с кол-вом заведений по улицам и районам
area10=area10.query('id>102')
#выбрали в таблице районы и улицы с количеством больше 102
area10
area10['area'].unique()
#выбрали все уникальные районы, в которые па
# Out:
#                      streets                             area   id
# 1299           проспект мира                Ярославский Район  203
# 1298           проспект мира                   Район Свиблово  203
# 1297           проспект мира                  Район Ростокино  203
# 1296           проспект мира               Район Марьина роща  203
# 1295           проспект мира               Останкинский район  203
# 1294           проспект мира                  Мещанский район  203
# 1293           проспект мира               Алексеевский район  203
# 1307       профсоюзная улица                   Район Коньково  182
# 1305       профсоюзная улица              Академический район  182
# 1310       профсоюзная улица                    Район Ясенево  182
# 1309       профсоюзная улица                  Район Черемушки  182
# 1308       профсоюзная улица                Район Теплый Стан  182
# 1306       профсоюзная улица                Обручевский район  182
# ...

# %%
pd.options.display.max_colwidth = 250

# %%
area10.groupby('streets').agg({'area': set})
# Out:
#                                                                                                                                                                                                       area
# streets
# варшавское шоссе        {Район Чертаново Южное, Район Чертаново Центральное, Район Чертаново Северное, Район Южное Бутово, Район Нагатино-Садовники, Донской район, Район Северное Бутово, Нагорный район}
# каширское шоссе                                                                      {Район Нагатино-Садовники, Район Москворечье-Сабурово, Район Орехово-Борисово Северное, Район Орехово-Борисово Южное}
# кировоградская улица                                                                                                        {Район Чертаново Центральное, Район Чертаново Северное, Район Чертаново Южное}
# ...

# %%
(area10.pivot_table(index=['streets'], values ='area', aggfunc='count').reset_index()
.sort_values(by='area', ascending=False))
# Out:
#                    streets  area
# 0         варшавское шоссе     8
# 5       ленинский проспект     8
# 9            проспект мира     7
# 10       профсоюзная улица     6
# 8     проспект вернадского     5
# 1          каширское шоссе     4
# 4   ленинградский проспект     4
# 2     кировоградская улица     3
# 3     кутузовский проспект     2
# 6             лесная улица     1
# 7   пресненская набережная     1

# %% [markdown]
# Одна улица попадает сразу в несколько районов.
#
# Название уникальных районов в которые попадают то-10 улиц по количеству заведений:
#
#        'Алексеевский район', 'Ярославский Район', 'Мещанский район',
#        'Останкинский район', 'Район Марьина роща', 'Район Свиблово',
#        'Район Ростокино', 'Академический район', 'Обручевский район',
#        'Район Коньково', 'Район Теплый Стан', 'Район Черемушки',
#        'Район Ясенево', 'Хорошевский район', 'Район Сокол',
#        'Район Беговой', 'Район Аэропорт', 'Пресненский район',
#        'Донской район', 'Район Чертаново Северное',
#        'Район Северное Бутово', 'Район Нагатино-Садовники',
#        'Нагорный район', 'Район Южное Бутово', 'Район Чертаново Южное',
#        'Район Чертаново Центральное', 'Район Проспект Вернадского',
#        'Район Гагаринский', 'Ломоносовский район',
#        'Район Тропарево-Никулино', 'Район Якиманка', 'Район Раменки',
#        'Район Крюково', 'Район Дорогомилово', 'Район Фили-Давыдково',
#        'Район Орехово-Борисово Северное', 'Район Орехово-Борисово Южное',
#        'Район Москворечье-Сабурово'
#
# Выделим топ 10 районов по количеству заведений в них.

# %%
(area10.pivot_table(index='area', values ='id', aggfunc='sum').reset_index()
.sort_values(by='id', ascending=False)).head(10)
# Out:
#                           area   id
# 26           Район Теплый Стан  330
# 6            Обручевский район  330
# 2                Донской район  310
# 3          Ломоносовский район  276
# 20  Район Проспект Вернадского  276
# 11           Район Гагаринский  276
# 27    Район Тропарево-Никулино  276
# 17    Район Нагатино-Садовники  273
# 30    Район Чертаново Северное  270
# 32       Район Чертаново Южное  270

# %%
plt.figure(figsize=(15, 8));
ax=sns.barplot(data=(area10.pivot_table(index='area', values ='id', aggfunc='sum').reset_index()
.sort_values(by='id', ascending=False)).head(11), y='id', x='area', color='mediumpurple')
plt.title("Топ 10 районов по количеству объектов");
plt.xlabel("Количество");
plt.ylabel("Район");
plt.xticks(rotation=45)
for p in ax.patches:
    height = p.get_height();
    ax.text(p.get_x()+p.get_width()/2.,
            height + 2,
            '{:1.0f}'.format(height),
            ha="center");
plt.show();

# %% [markdown]
# Больше всего заведений находится в районе Теплый Стан и Обручевском районе - 330 заведений

# %% [markdown]
# ## Найдите число улиц с одним объектом общественного питания. Воспользуйтесь внешней информацией и ответьте на вопрос — в каких районах Москвы находятся эти улицы?

# %%
area1=(df.pivot_table(index=['streets', 'area'], values ='id', aggfunc='count').reset_index()
.sort_values(by='id', ascending=False))
area1=area1.query('id==1')
area1
# Out:
#                                       streets                       area  id
# 41                     1-й саратовский проезд         Район Текстильщики   1
# 2004                      улица пржевальского  Район Очаково-Матвеевское   1
# 61    1-я линия хорошёвского серебряного бора    Район Хорошево-Мневники   1
# 2218                         чукотский проезд         Бабушкинский район   1
# 50                   1-я аэропортовская улица             Район Аэропорт   1
# ...                                       ...                        ...  ..
# 703                          калошин переулок                Район Арбат   1
# 702                        калибровская улица         Останкинский район   1
# 701                         калашный переулок                Район Арбат   1
# 700                         калашный переулок          Пресненский район   1
# 2281                          яхромская улица          Дмитровский район   1
#
# [564 rows x 3 columns]

# %%
(area1.pivot_table(index=['area'], values ='id', aggfunc='count').reset_index()
.sort_values(by='id', ascending=False))
# Out:
#                     area  id
# 95       Таганский район  27
# 81       Район Хамовники  26
# 3        Басманный район  25
# 20     Пресненский район  20
# 96        Тверской район  20
# ..                   ...  ..
# 83        Район Царицыно   1
# 36      Район Ивановское   1
# 46    Район Левобережный   1
# 79  Район Филевский Парк   1
# 50         Район Марфино   1
#
# [101 rows x 2 columns]

# %% [markdown]
# Число улиц в Москве с 1 объектом общественного питания составляет 564 улицы. Эти улицы расположены в 101 районе Москвы.

# %% [markdown]
# ## Посмотрите на распределение количества посадочных мест для улиц с большим количеством объектов общественного питания. Какие закономерности можно выявить?

# %%
top10.query('id>102')['streets'].unique()
# Out:
# array(['проспект Мира', 'Профсоюзная улица', 'Ленинградский проспект',
#        'Пресненская набережная', 'Варшавское шоссе', 'Ленинский проспект',
#        'проспект Вернадского', 'Кутузовский проспект', 'Каширское шоссе',
#        'Кировоградская улица'], dtype=object)

# %%
a= ['проспект мира', 'профсоюзная улица', 'ленинградский проспект',
       'пресненская набережная', 'варшавское шоссе', 'ленинский проспект',
       'проспект вернадского', 'кутузовский проспект', 'каширское шоссе',
       'кировоградская улица']
top10_number=data.query("streets== @a ")

# %%
top10_number['number'].describe()
# Out:
# count    1495.000000
# mean       58.271572
# std        90.230649
# min         0.000000
# 25%        12.000000
# 50%        40.000000
# 75%        75.000000
# max      1700.000000
# Name: number, dtype: float64

# %%
top10_number['number'].hist(bins=25, range=(0, 300));
plt.title("Характеристика посадочных мест");
plt.xlabel("Количество мест");
plt.ylabel("Количество заведений");

# %%
top10_number.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1495 entries, 151 to 15358
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1495 non-null   int64
#  1   object_name      1495 non-null   object
#  2   chain            1495 non-null   object
#  3   object_type      1495 non-null   object
#  4   address          1495 non-null   object
#  5   number           1495 non-null   int64
#  6   object_name_new  1495 non-null   object
#  7   streets          1495 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 105.1+ KB

# %%
top10_number.groupby('streets')[['number']].median().reset_index().sort_values(by='number')['streets'].to_list()
# Out:
# ['профсоюзная улица',
#  'каширское шоссе',
#  'варшавское шоссе',
#  'кировоградская улица',
#  'пресненская набережная',
#  'кутузовский проспект',
#  'ленинградский проспект',
#  'проспект вернадского',
#  'ленинский проспект',
#  'проспект мира']

# %%
plt.figure(figsize=(10, 7));
a=sns.boxplot(data=top10_number, y='streets', x='number', showfliers=False, 
              order=top10_number.groupby('streets')[['number']]
              .median().reset_index().sort_values(by='number')['streets'].to_list());
plt.title("Характеристика посадочных мест");
plt.xlabel("Количество мест");
plt.ylabel("Улицы");
a.set(xlim=(-10, 300));

# %% [markdown]
# На гистограмме видно, что на популярных улицах очень много заведений с количеством посадочных мест равным 0.
#
# По диаграмме размаха видно, что в основном количество мест в заведениях на разных улицах распределенно равномерно. На каждой улице есть выбросы по количеству посадочных мест. Среднее значение посадочных мест равно 58, а медианное значение равно 40.

# %% [markdown]
# ## Вывод и рекомендации

# %% [markdown]
# Проведя исследование заведений общественного питания в Москве для будущего открытия кафе, можно сделать выводы и дать несколько рекомендаций.
#
# 1. Исследовали виды объектов общественного питания. В топ-5 входит:
#
# |   |               Вид объекта | Кол-во | %         |
# |--:|--------------------------:|-------:|-----------|
# |   |                      кафе |   6071 | 39.73 |
# |   |                  столовая |   2584 | 16.91 |
# |   |                  ресторан |   2282 | 14.93 |
# |   |                  фаст-фуд |   1897 | 12.41|
# |   |                       бар |    855 |  5.59|
# |   |                     буфет |    576 |  3.77|
# |   |                 кафетерий |    395 |  2.59 |
# |   |                закусочная |    348 |  2.28 |
# |   | магазин (отдел кулинарии) |    273 |  1.79 |
#
# В Москве большую часть от всех заведений занимает кафе, их процент от общего количества составляет 39.7%.
#
# 2. Посмотрели соотношение сетевых заведений к несетевым.
#
# Сетевых заведений всего 2 964, а несетевых 12 317.
#
# Сетевое распространение относительно всех заведений каждого типа больше всего характерно для:
#
# - фаст-фуда - 41,54%
# - отдела кулинарии - 28,57%
# - ресторанов - 23,79%
# - кафе - 22,99%
#
# Также сетевые заведения имеют в основном много посадочных мест 82,3%. Мало посадочных мест имеет всего лишь 17,7% сетевых заведений.
#
# 3. Выяснили в каких заведениях в среднем больше всего посадочных мест.
#
# |               Вид объекта | Кол-во мест |
# |--------------------------:|-------------|
# |                  столовая |  130.337848 |
# |                  ресторан |   96.884750 |
# |                     буфет |   51.425347 |
# |                       бар |   43.533333 |
# |                      кафе |   39.785703 |
# |                  фаст-фуд |   20.808645 |
# |                 кафетерий |    9.184810 |
# |                закусочная |    7.847701 |
# | магазин (отдел кулинарии) |    5.589744 |
#
# Лидером оказались столовые и рестораны, это можно объяснить тем, что в заведениях такого типа проводят различные мероприятия, с большим количеством гостей.
#
# 4. Узнали топ-10 улиц по количествам объектов общественного питания.
#
# |                  Улицы | Кол-во |
# |-----------------------:|--------|
# |          проспект Мира |    203 |
# |      Профсоюзная улица |    182 |
# | Ленинградский проспект |    172 |
# | Пресненская набережная |    167 |
# |       Варшавское шоссе |    162 |
# |     Ленинский проспект |    148 |
# |   проспект Вернадского |    128 |
# |   Кутузовский проспект |    114 |
# |        Каширское шоссе |    111 |
# |   Кировоградская улица |    108 |
#
# Самая популярная улица - это проспект Мира, на нем находится 203 заведения, далее идут Профсоюзная улица, Ленинградский проспект. Такое большое количество заведений на них можно объяснить тем, что это одни из популярных и длинных улиц Москвы, также эти улицы пересекают несколько районов.
#
# * **Проспект Мира** проходит через: Ярославский Район, Район Свиблово, Район Ростокино, Район Марьина роща, Останкинский район, Мещанский район, Алексеевский район;
# * **Профсоюзная улица** проходит через: Район Коньково, Академический район, Район Ясенево, Район Черемушки, Район Теплый Стан, Обручевский район;
# * **Ленинградский проспект** проходит через: Район Беговой, Район Аэропорт, Хорошевский район, Район Сокол.
#
# 5. Нашли улицы где располагается только одно заведение.
#
# Таких улиц оказалось 564. Такое маленькое количество заведений на одной улице можно объяснить тем, что либо эта улица находится в непопулярном районе, либо же улица очень маленькая по протяженности.
#
# 6. Посмотрели на распредление мест на улицах с большим количетсвом объектов общественного питания.
#
# По гистограмме приведенной ниже видно, что больше всего заведений с количеством посадочных мест равным 0.
#
# ![download.png](attachment:download.png)
#
# 7. Проведя анализ информации по заведениям Москвы, можно дать несколько рекомендаций для открытия нового кафе:
#
#     * Маленькие кафе очень популярны в Москве, поэтому открытие кафе такого типа, вполне вероятно будет приносить прибыль владельцам.
#     * Открывать кафе лучше на одной популярных улицах, а именно:
#
#        * проспект Мира;
#        * Профсоюзная улица;
#        * Ленинградский проспект;
#        * Пресненская набережная;
#        * Варшавское шоссе;
#        * Ленинский проспект;
#        * пропект Вернадского;
#        * Кутузовский проспект;
#        * Каширское шоссе;
#        * Кировоградская улица.
#
#     * Еще стоит взять во внимание районы в которых расположенно много заведений - Теплый Стан, Обручевский район и Донской районе.
#     * Также можно учесть при открытии нового кафе улицы, которые расположены в перспективных районах.
#
#     * Количество посадочных мест стоит делать в диапазоне примерно от 12 до 40.
#     * Развитие сети возможно, но для этого нужно открыть первое кафе и наблюдать за тем, насколько оно пользуется популярностью. И уже на основании данных работы кафе, провести анализ и думать о дальнейшем развитии сети.

# %% [markdown]
# Презентация: <https://disk.yandex.ru/i/BTQ10rxMGNiyyA>
